# %%
a,b,c = float(input()),float(input()),float(input())
d= ((b*b) -(4*a*c))
from math import *
x1=((-(b)+(d**0.5))/(2*a)) 

x2=((-(b)-(d**0.5))/(2*a))
if d<0:
    print('Нет корней')
elif d==0:
    print(-b/(2*a))
elif d>0:
    print(min(x1,x2))
    print(max(x1,x2))
# Out:
#  7
#  9
#  4
# Нет корней
