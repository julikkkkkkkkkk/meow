# %%
string = input('Введите температуру в C/F : ')

if string[-1] == 'C':
    print(int(string[:-1])*1.8+32) # хотим сделать срез и исключить последний элементтстроки и перевести в F
elif string[-1]== 'F':
    print((int(string[:-1])-32)/1.8)
else:
    print('ошибка')
# Out:
# Введите температуру в C/F :  6П
# ошибка
